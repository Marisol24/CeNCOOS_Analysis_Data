# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from matplotlib import mlab
import scipy.signal as signal
import xarray as xr
from scipy import stats
import pandas as pd
from scipy import linalg
import os

# %% [markdown]
# *MLML Shore Station Data>Moss_Landing>netcdf*
# https://drive.google.com/drive/u/3/folders/1kHGUe0LtATtH5veMkt-f35pgTuz2AGWZ

# %%
local_dataset_2010='Data/moss_landing_2010.nc'
local_dataset_2011 = 'Data/moss_landing_2011.nc'
local_dataset_2012='Data/moss_landing_2012.nc'
local_dataset_2013='Data/moss_landing_2013.nc'
local_dataset_2014='Data/moss_landing_2014.nc'
local_dataset_2015='Data/moss_landing_2015.nc'

# %%
ds_2010= xr.open_dataset(local_dataset_2010)
ds_2011=xr.open_dataset(local_dataset_2011)
ds_2012=xr.open_dataset(local_dataset_2012)
ds_2013=xr.open_dataset(local_dataset_2013)
ds_2014= xr.open_dataset(local_dataset_2014)
ds_2015=xr.open_dataset(local_dataset_2015)

# %%
df10= ds_2010.to_dataframe()
df11= ds_2011.to_dataframe()
df12= ds_2012.to_dataframe()
df13= ds_2013.to_dataframe()
df14 = ds_2014.to_dataframe()
df15 = ds_2015.to_dataframe()

# %%
#df10.head
# df11.head
#df12.head
#df13.head
#df14.head
#df15.head

# %%
#Temp 2010
plt.figure(figsize=(10,4)) #made the graph bigger 
plt.plot(df10.index,df10['temp'])
plt.xticks(rotation=20) #rotated the x axus by 20 degrees
plt.title('Temp of 2010')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')

#Temp 2011
plt.figure()
plt.plot(df11.index,df11['temp'])
plt.title('Temp of 2011')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')


#Temp 2012
plt.figure()
plt.plot(df12.index,df12['temp'])
plt.title('Temp of 2012')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')

#Temp 2013
plt.figure()
plt.plot(df13.index,df13['temp'])
plt.title('Temp of 2013')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')

#Temp 2014
plt.figure()
plt.plot(df14.index,df14['temp'])
plt.title('Temp of 2014')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')

#Temp 2015
plt.figure(figsize=(10,5)) #made the graph bigger 
plt.plot(df15.index,df15['temp'])
plt.xticks(rotation=20) #rotated the x axus by 20 degrees
plt.title('Temp of 2015')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# *no nitrate sensor*

# %%
# #Nitrate 2010
# plt.figure()
# plt.plot(df10.index,df10['nitrate'])
# plt.title('Nitrate 2010')
# plt.ylabel('Nitrate (uM)')
# plt.xlabel('Year-Month')

# #Nitrate 2011
# plt.figure()
# plt.plot(df11.index,df11['nitrate'])
# plt.title('Nitrate 2011')
# plt.ylabel('Nitrate (uM)')
# plt.xlabel('Year-Month')


# #Nitrate 2012
# plt.figure()
# plt.plot(df12.index,df12['nitrate'])
# plt.title('Nitrate 2012')
# plt.ylabel('Nitrate (uM)')
# plt.xlabel('Year-Month')

# #Nitrate 2013
# plt.figure()
# plt.plot(df13.index,df13['nitrate'])
# plt.title('Nitrate 2013')
# plt.ylabel('Nitrate (uM)')
# plt.xlabel('Year-Month')

# #Nitrate 2014
# plt.figure()
# plt.plot(df14.index,df14['nitrate'])
# plt.title('Nitrate 2014')
# plt.ylabel('Nitrate (uM)')
# plt.xlabel('Year-Month')

# #Nitrate 2015
# plt.figure()
# plt.plot(df15.index,df15['nitrate'])
# plt.title('Nitrate 2015')
# plt.ylabel('Nitrate (uM)')
# plt.xlabel('Year-Month')

# %%
#Salinity 2010
plt.figure()
plt.plot(df10.index,df10['sal']) 

plt.title('Time Series of sal 2010')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')

#Salinity 2011
plt.figure()
plt.plot(df11.index,df11['sal']) 

plt.title('Time Series of sal 2011')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')

#Salinity 2012
plt.figure()
plt.plot(df12.index,df12['sal']) 

plt.title('Time Series of sal 2012')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')

#Salinity 2013
plt.figure()
plt.plot(df13.index,df13['sal']) 

plt.title('Time Series of sal 2013')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')

#Salinity 2014
plt.figure()
plt.plot(df14.index,df14['sal']) 

plt.title('Time Series of sal 2014')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')

#Salinity 2015
plt.figure()
plt.plot(df15.index,df15['sal']) 

plt.title('Time Series of sal 2015')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#DO 2010
plt.figure()
plt.plot(df10.index,df10['do2']) 

plt.title('Time Series of DO 2010')
plt.ylabel('DO (mg/L)') 
plt.xlabel('Year-Month')

#DO 2011
plt.figure()
plt.plot(df11.index,df11['do2']) 

plt.title('Time Series of DO 2011')
plt.ylabel('DO (mg/L)') 
plt.xlabel('Year-Month')

#DO 2012
plt.figure()
plt.plot(df12.index,df12['do2']) 

plt.title('Time Series of DO 2012')
plt.ylabel('DO (mg/L)') 
plt.xlabel('Year-Month')

#DO 2013
plt.figure()
plt.plot(df13.index,df13['do2']) 

plt.title('Time Series of DO 2013')
plt.ylabel('DO (mg/L)') 
plt.xlabel('Year-Month')

#DO 2014
plt.figure()
plt.plot(df14.index,df14['do2']) 

plt.title('Time Series of DO 2014')
plt.ylabel('DO (mg/L)') 
plt.xlabel('Year-Month')

#DO 2015
plt.figure()
plt.plot(df15.index,df15['do2']) 

plt.title('Time Series of DO 2015')
plt.ylabel('DO (mg/L)') 
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# no pH data for 2010 and 2011

# %%
# df10.head
# df11.head


# #pH 2010
# plt.figure()
# plt.plot(df10.index,df10['ph']) 

# plt.title('Time Series of pH 2010')
# plt.ylabel('pH (-log[H +] and [H+]) ') 
# plt.xlabel('Year-Month')

# #pH 2011
# plt.figure()
# plt.plot(df11.index,df11['ph']) 

# plt.title('Time Series of pH 2011')
# plt.ylabel('pH (-log[H +] and [H+]) ') 
# plt.xlabel('Year-Month')

# %%
#pH 2012
plt.figure()
plt.plot(df12.index,df12['ph']) 

plt.title('Time Series of pH 2012')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')

#pH 2013
plt.figure()
plt.plot(df13.index,df13['ph']) 

plt.title('Time Series of pH 2013')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')

#pH 2014
plt.figure()
plt.plot(df14.index,df14['ph']) 

plt.title('Time Series of pH 2014')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')

#pH 2015
plt.figure()
plt.plot(df15.index,df15['ph']) 

plt.title('Time Series of pH 2015')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#Fluorescence
plt.figure()
plt.plot(df10.index,df10['fluor']) 

plt.title('Time Series of Fluor 2010')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df11.index,df11['fluor']) 

plt.title('Time Series of Fluor 2011')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df12.index,df12['fluor']) 

plt.title('Time Series of Fluor 2012')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df13.index,df13['fluor']) 

plt.title('Time Series of Fluor 2013')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df14.index,df14['fluor']) 

plt.title('Time Series of Fluor 2014')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df15.index,df15['fluor']) 

plt.title('Time Series of Fluor 2015')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#Raw Data

# %%
df10= ds_2010.to_dataframe()
df11= ds_2011.to_dataframe()
df12= ds_2012.to_dataframe()
df13= ds_2013.to_dataframe()
df14 = ds_2014.to_dataframe()
df15 = ds_2015.to_dataframe()

# %%
################################################################################################

# %%
df10= ds_2010.to_dataframe().reset_index() #maybe without reset index?
df11= ds_2011.to_dataframe().reset_index()
df12= ds_2012.to_dataframe().reset_index()
df13= ds_2013.to_dataframe().reset_index()
df14 = ds_2014.to_dataframe().reset_index()
df15 = ds_2015.to_dataframe().reset_index()

# %%
#can't drop na in any of them, it erases the whole data set

# %%
#df10
#df11
#df12
#df13
#df14
#df15

# %%
#Without .dropna () and took out (df['nitrate_flg'] == 1) & because of no nitrate sensor in from 2010-2015

# %%
ii_df10=np.array((df10['temp_flg'] == 1) & (df10['sal_flg'] == 1) & (df10['fluor_flg'] == 1) & (df10['ph_flg'] == 1) & (df10['do2_flg'] == 1))

# %%
df10['temp_flg']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 32112    1.0
# 32113    1.0
# 32114    1.0
# 32115    1.0
# 32116    1.0
# Name: temp_flg, Length: 32117, dtype: float64

# %%
ii_df10
# Out:
# array([False, False, False, ..., False, False, False])

# %%
ii_df11=np.array((df11['temp_flg'] == 1) & (df11['sal_flg'] == 1) & (df11['fluor_flg'] == 1) & (df11['ph_flg'] == 1) & (df11['do2_flg'] == 1))

# %%
ii_df12=np.array((df12['temp_flg'] == 1) & (df12['sal_flg'] == 1) & (df12['fluor_flg'] == 1) & (df12['ph_flg'] == 1) & (df12['do2_flg'] == 1))

# %%
ii_df13=np.array((df13['temp_flg'] == 1) & (df13['sal_flg'] == 1) & (df13['fluor_flg'] == 1) & (df13['ph_flg'] == 1) & (df13['do2_flg'] == 1))

# %%
ii_df14=np.array((df14['temp_flg'] == 1) & (df14['sal_flg'] == 1) & (df14['fluor_flg'] == 1) & (df14['ph_flg'] == 1) & (df14['do2_flg'] == 1))

# %%
ii_df15=np.array((df15['temp_flg'] == 1) & (df15['sal_flg'] == 1) & (df15['fluor_flg'] == 1) & (df15['ph_flg'] == 1) & (df15['do2_flg'] == 1))

# %%
############################################################################################################

# %%
temp_df10= np.array(df10['temp'][ii_df10])
# nitrate_df = np.array(df['nitrate'][ii_df])
sal_df10= np.array(df10['sal'][ii_df10])
fluor_df10= np.array(df10['fluor'][ii_df10])
pH_df10= np.array(df10['ph'][ii_df10])
do2_df10= np.array(df10['do2'][ii_df10])

# %%
temp_df11= np.array(df11['temp'][ii_df11])
#nitrate_df11 = np.array(df11['nitrate'][ii_df11])
sal_df11= np.array(df11['sal'][ii_df11])
fluor_df11= np.array(df11['fluor'][ii_df11])
pH_df11= np.array(df11['ph'][ii_df11])
do2_df11= np.array(df11['do2'][ii_df11])

# %%
temp_df12= np.array(df12['temp'][ii_df12])
# nitrate_df = np.array(df['nitrate'][ii_df])
sal_df12= np.array(df12['sal'][ii_df12])
fluor_df12= np.array(df12['fluor'][ii_df12])
pH_df12= np.array(df12['ph'][ii_df12])
do2_df12= np.array(df12['do2'][ii_df12])

# %%
temp_df13= np.array(df13['temp'][ii_df13])
# nitrate_df = np.array(df['nitrate'][ii_df])
sal_df13= np.array(df13['sal'][ii_df13])
fluor_df13= np.array(df13['fluor'][ii_df13])
pH_df13= np.array(df13['ph'][ii_df13])
do2_df13= np.array(df13['do2'][ii_df13])

# %%
temp_df14= np.array(df14['temp'][ii_df14])
# nitrate_df = np.array(df['nitrate'][ii_df])
sal_df14= np.array(df14['sal'][ii_df14])
fluor_df14= np.array(df14['fluor'][ii_df14])
pH_df14= np.array(df14['ph'][ii_df14])
do2_df14= np.array(df14['do2'][ii_df14])

# %%
temp_df15= np.array(df15['temp'][ii_df15])
# nitrate_df = np.array(df['nitrate'][ii_df])
sal_df15= np.array(df15['sal'][ii_df15])
fluor_df15= np.array(df15['fluor'][ii_df15])
pH_df15= np.array(df15['ph'][ii_df15])
do2_df15= np.array(df15['do2'][ii_df15])

# %% [markdown]
# PCA_df10 and PCA_df11, no data.

# %%
PCA_df10 = pd.DataFrame(temp_df10, columns=['temp']) 
#PCA_df['nitrate'] = nitrate_df.tolist()
PCA_df10['sal'] = sal_df10.tolist()
PCA_df10['fluor'] = fluor_df10.tolist()
PCA_df10['pH'] = pH_df10.tolist()
PCA_df10['do2'] = do2_df10.tolist()

# %%
PCA_df10
# Out:
# Empty DataFrame
# Columns: [temp, sal, fluor, pH, do2]
# Index: []

# %%
PCA_df11 = pd.DataFrame(temp_df11, columns=['temp'])
#PCA_df['nitrate'] = nitrate_df11.tolist()
PCA_df11['sal'] = sal_df11.tolist()
PCA_df11['fluor'] = fluor_df11.tolist()
PCA_df11['pH'] = pH_df11.tolist()
PCA_df11['do2'] = do2_df11.tolist()

# %%
PCA_df11
# Out:
# Empty DataFrame
# Columns: [temp, sal, fluor, pH, do2]
# Index: []

# %%
PCA_df12 = pd.DataFrame(temp_df12, columns=['temp'])
#PCA_df['nitrate'] = nitrate_df.tolist()
PCA_df12['sal'] = sal_df12.tolist()
PCA_df12['fluor'] = fluor_df12.tolist()
PCA_df12['pH'] = pH_df12.tolist()
PCA_df12['do2'] = do2_df12.tolist()

# %%
PCA_df12
# Out:
#             temp        sal     fluor        pH     do2
# 0      10.881165  33.270593  1.005244  7.083295   39.00
# 1      10.822272  33.271439  1.456038  7.092423   41.24
# 2      11.402962  33.261022  0.960800  7.073153   35.16
# 3      11.459638  33.260997  0.878260  7.077210   38.08
# 4      11.528656  33.259112  0.725879  7.085324   40.60
# ...          ...        ...       ...       ...     ...
# 29937  10.967989  33.575561  0.325879  7.778812  142.83
# 29938  11.040390  33.579165  0.325879  7.776340  144.56
# 29939  11.195833  33.582703  0.294133  7.773867  147.32
# 29940  11.250931  33.597795  0.319530  7.763978  153.83
# 29941  11.191951  33.596631  0.389371  7.757797  145.13
#
# [29942 rows x 5 columns]

# %%
PCA_df13 = pd.DataFrame(temp_df13, columns=['temp'])
#PCA_df['nitrate'] = nitrate_df.tolist()
PCA_df13['sal'] = sal_df13.tolist()
PCA_df13['fluor'] = fluor_df13.tolist()
PCA_df13['pH'] = pH_df13.tolist()
PCA_df13['do2'] = do2_df13.tolist()

# %%
PCA_df13
# Out:
#             temp        sal     fluor        pH     do2
# 0      10.949293  33.607275  0.319530  7.757797  147.51
# 1      11.761021  33.619701  0.338578  7.746671  138.14
# 2      11.897949  33.619588  0.313181  7.745435  135.75
# 3      11.842595  33.619547  0.306832  7.745435  134.44
# 4      10.921238  33.605841  0.294133  7.755324  140.38
# ...          ...        ...       ...       ...     ...
# 78326  12.742761  33.407594  0.294133  7.956902  230.98
# 78327  12.761739  33.407753  0.287784  7.956902  231.85
# 78328  12.816367  33.410367  0.275086  7.956902  231.51
# 78329  12.588466  33.405080  0.287784  7.960677  230.24
# 78330  12.736686  33.404969  0.281435  7.959418  228.67
#
# [78331 rows x 5 columns]

# %%
PCA_df14 = pd.DataFrame(temp_df14, columns=['temp'])
#PCA_df['nitrate'] = nitrate_df.tolist()
PCA_df14['sal'] = sal_df14.tolist()
PCA_df14['fluor'] = fluor_df14.tolist()
PCA_df14['pH'] = pH_df14.tolist()
PCA_df14['do2'] = do2_df14.tolist()

# %%
PCA_df14
# Out:
#             temp        sal     fluor        pH     do2
# 0      12.756425  33.408458  0.294133  7.958160  227.75
# 1      12.814092  33.399391  0.319530  7.958160  226.77
# 2      12.874742  33.410639  0.294133  7.960677  229.05
# 3      12.820159  33.411006  0.306832  7.959418  231.22
# 4      12.512333  33.408407  0.306832  7.969485  233.51
# ...          ...        ...       ...       ...     ...
# 68552  13.786749  32.957687  0.173498  7.902938  176.98
# 68553  13.764716  32.946082  0.173498  7.901691  177.15
# 68554  13.755392  32.944253  0.167149  7.901691  177.25
# 68555  13.740132  32.939647  0.179848  7.902938  177.49
# 68556  13.720629  32.933759  0.173498  7.901691  177.88
#
# [68557 rows x 5 columns]

# %%
PCA_df15 = pd.DataFrame(temp_df15, columns=['temp'])
#PCA_df['nitrate'] = nitrate_df.tolist()
PCA_df15['sal'] = sal_df15.tolist()
PCA_df15['fluor'] = fluor_df15.tolist()
PCA_df15['pH'] = pH_df15.tolist()
PCA_df15['do2'] = do2_df15.tolist()

# %%
PCA_df15
# Out:
#             temp        sal     fluor        pH     do2
# 0      13.706210  32.929406  0.179848  7.902938  179.04
# 1      13.711299  32.928971  0.179848  7.905433  179.37
# 2      13.731653  32.930190  0.186197  7.909174  179.63
# 3      13.718933  32.931312  0.224292  7.910422  179.90
# 4      13.755392  32.931450  0.173498  7.907927  179.27
# ...          ...        ...       ...       ...     ...
# 82916  14.457828  33.002377  0.446514  8.334470  285.66
# 82917  14.445045  33.001739  0.440165  8.336964  288.72
# 82918  14.406686  33.000790  0.433816  8.335717  289.68
# 82919  14.082456  32.999935  0.440165  8.335717  294.49
# 82920  14.148172  32.999800  0.440165  8.336964  303.14
#
# [82921 rows x 5 columns]

# %%
# R_10= np.corrcoef(PCA_df10, rowvar=False) 
# R_11= np.corrcoef(PCA_df11, rowvar=False) 
R_12= np.corrcoef(PCA_df12, rowvar=False) 
R_13= np.corrcoef(PCA_df13, rowvar=False) 
R_14= np.corrcoef(PCA_df14, rowvar=False) 
R_15= np.corrcoef(PCA_df15, rowvar=False)

# %%
#val, vec = linalg.eig(R_10) Error: no inf or nan's
#val, vec = linalg.eig(R_11) Error: no inf or nan's
val, vec = linalg.eig(R_12) #works
val, vec = linalg.eig(R_13) #works
val, vec = linalg.eig(R_14)  #works
val, vec = linalg.eig(R_15)  #works

# %%
#2010

# %%
#2011

# %%
#####################################################################################################

# %%
#2012

# %%
 R_12= np.corrcoef(PCA_df12, rowvar=False) 
val, vec = linalg.eig(R_12) #works

# %%
vec
# Out:
# array([[-5.36573517e-01,  1.16514462e-01, -3.10717813e-01,
#         -7.56533266e-01, -1.72119433e-01],
#        [ 2.08562808e-02, -7.07972710e-01,  6.05161004e-01,
#         -3.57765457e-01, -6.42159993e-02],
#        [-3.38299817e-02,  6.76421836e-01,  6.95293679e-01,
#         -1.90748067e-01,  1.46597772e-01],
#        [-5.88486299e-01,  3.15923373e-04,  2.29364938e-01,
#          4.64462177e-01, -6.20765969e-01],
#        [-6.03484287e-01, -1.66290174e-01,  3.45401891e-02,
#          2.18062736e-01,  7.47937104e-01]])

# %%
val=np.real(val)

# %%
np.real(val)
np.sum(val)
# Out:
# 5.0

# %%
pctvar = val/np.sum(val)*100
pctvar
# Out:
# array([45.5561247 , 26.2441416 , 15.60009972,  8.56471025,  4.03492374])

# %%
A = np.dot(vec, np.diag(val**.5))
A
# Out:
# array([[-8.09818367e-01,  1.33469189e-01, -2.74419419e-01,
#         -4.95073145e-01, -7.73094485e-02],
#        [ 3.14771392e-02, -8.10994120e-01,  5.34465436e-01,
#         -2.34120663e-01, -2.88433642e-02],
#        [-5.10575712e-02,  7.74852087e-01,  6.14068713e-01,
#         -1.24824974e-01,  6.58460968e-02],
#        [-8.88167229e-01,  3.61895303e-04,  2.02570276e-01,
#          3.03942683e-01, -2.78824266e-01],
#        [-9.10802797e-01, -1.90488068e-01,  3.05051665e-02,
#          1.42699613e-01,  3.35944663e-01]])

# %%
print('PC1 loading')
print(A[:,0])
print('temp', 'sal', 'fluor', 'pH', 'do2')
# Out:
# PC1 loading
# [-0.80981837  0.03147714 -0.05105757 -0.88816723 -0.9108028 ]
# temp sal fluor pH do2

# %%
plt.figure
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.title('MLML Shore Data Station 2012 Data')
plt.xlabel('PC1 loading')
plt.ylabel('PC2 loading')

variables = ['temp', 'sal', 'fluor', 'pH', 'do2']
for i, txt in enumerate (variables):
    plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
    plt.text(A[i,0], A[i,1], txt)

# %%
tau = np.dot(PCA_df12, vec)
tau
# Out:
# array([[ -32.88296084,  -28.08996849,   20.42376074,   -8.53241109,
#           20.91048075],
#        [ -34.22376973,  -28.16498943,   20.83546904,   -8.08144738,
#           22.65636124],
#        [ -30.83829119,  -27.41390792,   20.08997483,   -9.7573375 ,
#           17.94898583],
#        ...,
#        [ -98.7970471 ,  -46.76761533,   23.92022007,   15.19481306,
#          101.31989404],
#        [-102.75001858,  -47.83725322,   24.15247947,   16.55788084,
#          106.18837423],
#        [ -97.46680772,  -46.34933678,   23.91674434,   14.68957874,
#           99.70562328]])

# %%
np.shape(tau)
# Out:
# (29942, 5)

# %%
plt.figure()
plt.plot(tau[:,1]) #PC1
plt.plot(tau[:,2]) #PC2
plt.plot(tau[:,3]) #PC3
plt.plot(tau[:,4]) #PC4
#plt.plot(tau[:,5]) #PC5

# %%
from scipy.signal import periodogram
from scipy.signal import welch

f,S = periodogram(PCA_df12['temp'],fs=288)
plt.figure()
plt.loglog(f,S,'k-')
plt.xlabel('frequency [int_ctd_pressure]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
plt.title('[periodogram, temp for 2012]')
# Out:
# Text(0.5, 1.0, '[periodogram, temp for 2012]')

# %%
N = len(PCA_df12['temp'])
fs = 288 
fN = 0.5* fs

# %%
PCA_df12['temp']
# Out:
# 0        10.881165
# 1        10.822272
# 2        11.402962
# 3        11.459638
# 4        11.528656
#            ...
# 29937    10.967989
# 29938    11.040390
# 29939    11.195833
# 29940    11.250931
# 29941    11.191951
# Name: temp, Length: 29942, dtype: float64

# %%
f, S = welch(PCA_df12['temp'], fs=288, nperseg=N)

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df12['temp'], fs=288., nperseg=winlen, window='hanning') 
plt.ylim(.00001) #use these to look at specific parts of the periodogram
#plt.xlim(.00001) #use these to look at specific parts of the periodogram
# Out:
# (1e-05, 40.242173155165716)

# %%
#raw periodogram (noisy, biased)
f, S = welch(PCA_df12['temp'], fs=288, nperseg=N) #window='boxcar'

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df12['temp'], fs=288., nperseg=winlen, window='hanning') 
#weighs middle more than edges like boxcar

plt.loglog(f2,S2)

# confidence intervals 

from scipy.stats import chi2

dof = N/winlen/2 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning) :)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
dof = N/winlen/8 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
#2013

# %%
 R_13= np.corrcoef(PCA_df13, rowvar=False) 
val, vec = linalg.eig(R_13) #works

# %%
vec
# Out:
# array([[-0.3295165 ,  0.3972351 ,  0.81278584, -0.24692762,  0.10967715],
#        [ 0.47382057,  0.43246712,  0.15890854,  0.70307189,  0.26249618],
#        [ 0.01550864,  0.79151832, -0.48498776, -0.36763414, -0.0537609 ],
#        [-0.56965568,  0.16852232, -0.07249693,  0.52316426, -0.60674211],
#        [-0.58494857, -0.01659637, -0.27140066,  0.1893699 ,  0.74029755]])

# %%
val, vec = linalg.eig(R_13)

# %%
val=np.real(val)

# %%
np.real(val)
np.sum(val)
# Out:
# 5.000000000000005

# %%
pctvar = val/np.sum(val)*100
pctvar
# Out:
# array([45.82633399, 23.87602949, 16.10848314,  9.07785254,  5.11130084])

# %%
A = np.dot(vec, np.diag(val**.5))
A
# Out:
# array([[-0.49879228,  0.43402392,  0.72943812, -0.16635897,  0.05544557],
#        [ 0.71722674,  0.47251886,  0.14261315,  0.47367046,  0.13270085],
#        [ 0.02347558,  0.8648226 , -0.43525433, -0.24768084, -0.02717799],
#        [-0.86229327,  0.18412955, -0.06506268,  0.35246389, -0.30672901],
#        [-0.88544225, -0.0181334 , -0.24356968,  0.12758144,  0.37424589]])

# %%
print('PC1 loading')
print(A[:,0])
print('temp', 'sal', 'fluor', 'pH', 'do2')
# Out:
# PC1 loading
# [-0.49879228  0.71722674  0.02347558 -0.86229327 -0.88544225]
# temp sal fluor pH do2

# %%
plt.figure
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.title('MLML Shore Data Station 2013 Data')
plt.xlabel('PC1 loading')
plt.ylabel('PC2 loading')

variables = ['temp', 'sal', 'fluor', 'pH', 'do2']
for i, txt in enumerate (variables):
    plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
    plt.text(A[i,0], A[i,1], txt)

# %%
tau = np.dot(PCA_df13, vec)
tau

np.shape(tau)
# Out:
# (78331, 5)

# %%
plt.figure()
plt.plot(tau[:,1]) #PC1
plt.plot(tau[:,2]) #PC2
plt.plot(tau[:,3]) #PC3
plt.plot(tau[:,4]) #PC4
#plt.plot(tau[:,5]) #PC5

# %%
from scipy.signal import periodogram
from scipy.signal import welch

f,S = periodogram(PCA_df13['temp'],fs=288)
plt.figure()
plt.loglog(f,S,'k-')
plt.xlabel('frequency [int_ctd_pressure]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
plt.title('[periodogram, temp for 2013]')
# Out:
# Text(0.5, 1.0, '[periodogram, temp for 2013]')

# %%
N = len(PCA_df13['temp'])
fs = 288 
fN = 0.5* fs

# %%
PCA_df13['temp']
# Out:
# 0        10.949293
# 1        11.761021
# 2        11.897949
# 3        11.842595
# 4        10.921238
#            ...
# 78326    12.742761
# 78327    12.761739
# 78328    12.816367
# 78329    12.588466
# 78330    12.736686
# Name: temp, Length: 78331, dtype: float64

# %%
f, S = welch(PCA_df13['temp'], fs=288, nperseg=N)

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df13['temp'], fs=288., nperseg=winlen, window='hanning') 
#plt.ylim(.00001) #use these to look at specific parts of the periodogram
#plt.xlim(.00001) #use these to look at specific parts of the periodogram

# %%
#raw periodogram (noisy, biased)
f, S = welch(PCA_df13['temp'], fs=288, nperseg=N) #window='boxcar'

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df13['temp'], fs=288., nperseg=winlen, window='hanning') 
#weighs middle more than edges like boxcar

plt.loglog(f2,S2)

# confidence intervals 

from scipy.stats import chi2

dof = N/winlen/2 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning) :)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
dof = N/winlen/8 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
#2014

# %%
 R_14= np.corrcoef(PCA_df14, rowvar=False) 
val, vec = linalg.eig(R_14) #works
vec
val, vec = linalg.eig(R_14)
val=np.real(val)
np.real(val)
np.sum(val)
# Out:
# 4.999999999999999

# %%
pctvar = val/np.sum(val)*100
pctvar
# Out:
# array([52.360471  , 26.4355594 , 15.94610748,  2.48211751,  2.7757446 ])

# %%
A = np.dot(vec, np.diag(val**.5))
A
# Out:
# array([[-0.87844028,  0.28720741,  0.274346  ,  0.21617669, -0.15445546],
#        [ 0.68591094, -0.61183612, -0.32021841,  0.18498594, -0.13573177],
#        [-0.39549446,  0.49549825, -0.7728698 , -0.00259664, -0.02703965],
#        [-0.7708528 , -0.57821471, -0.06231531, -0.18238673, -0.18521769],
#        [-0.79073542, -0.5339435 , -0.13523643,  0.09940852,  0.24793324]])

# %%
print('PC1 loading')
print(A[:,0])
print('temp', 'sal', 'fluor', 'pH', 'do2')
# Out:
# PC1 loading
# [-0.87844028  0.68591094 -0.39549446 -0.7708528  -0.79073542]
# temp sal fluor pH do2

# %%
plt.figure
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.title('MLML Shore Data Station 2014 Data')
plt.xlabel('PC1 loading')
plt.ylabel('PC2 loading')

variables = ['temp', 'sal', 'fluor', 'pH', 'do2']
for i, txt in enumerate (variables):
    plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
    plt.text(A[i,0], A[i,1], txt)

# %%
tau = np.dot(PCA_df14, vec)
tau

np.shape(tau)
# Out:
# (68557, 5)

# %%
plt.figure()
plt.plot(tau[:,1]) #PC1
plt.plot(tau[:,2]) #PC2
plt.plot(tau[:,3]) #PC3
plt.plot(tau[:,4]) #PC4
#plt.plot(tau[:,5]) #PC5

# %%
from scipy.signal import periodogram
from scipy.signal import welch

f,S = periodogram(PCA_df14['temp'],fs=288)
plt.figure()
plt.loglog(f,S,'k-')
plt.xlabel('frequency [int_ctd_pressure]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
plt.title('[periodogram, temp for 2014]')
# Out:
# Text(0.5, 1.0, '[periodogram, temp for 2014]')

# %%
N = len(PCA_df14['temp'])
fs = 288 
fN = 0.5* fs

# %%
PCA_df14['temp']
# Out:
# 0        12.756425
# 1        12.814092
# 2        12.874742
# 3        12.820159
# 4        12.512333
#            ...
# 68552    13.786749
# 68553    13.764716
# 68554    13.755392
# 68555    13.740132
# 68556    13.720629
# Name: temp, Length: 68557, dtype: float64

# %%
plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df14['temp'], fs=288., nperseg=winlen, window='hanning') 
#plt.ylim(.00001) #use these to look at specific parts of the periodogram
#plt.xlim(.00001) #use these to look at specific parts of the periodogram

# %%
#raw periodogram (noisy, biased)
f, S = welch(PCA_df14['temp'], fs=288, nperseg=N) #window='boxcar'

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df14['temp'], fs=288., nperseg=winlen, window='hanning') 
#weighs middle more than edges like boxcar

plt.loglog(f2,S2)

# confidence intervals 

from scipy.stats import chi2

dof = N/winlen/2 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning) :)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
dof = N/winlen/8 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
#2015

# %%
 R_15= np.corrcoef(PCA_df15, rowvar=False) 
val, vec = linalg.eig(R_15) #works
vec
val, vec = linalg.eig(R_15)
val=np.real(val)
np.real(val)
np.sum(val)
# Out:
# 4.999999999999998

# %%
pctvar = val/np.sum(val)*100
pctvar
# Out:
# array([58.15775974, 23.4845709 ,  4.18759457,  2.64987927, 11.52019552])

# %%
A = np.dot(vec, np.diag(val**.5))
A
# Out:
# array([[ 0.89812298, -0.23613833,  0.35760362,  0.09037365,  0.03957343],
#        [-0.70129656,  0.3924756 ,  0.11472828,  0.08784637,  0.57729236],
#        [ 0.16392789,  0.91694143,  0.06223318,  0.07557536, -0.3503733 ],
#        [ 0.85733613,  0.34925988, -0.0209592 , -0.26030194,  0.27348839],
#        [ 0.92062405,  0.04081759, -0.25303071,  0.20770374,  0.20885378]])

# %%
print('PC1 loading')
print(A[:,0])
print('temp', 'sal', 'fluor', 'pH', 'do2')

plt.figure
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.title('MLML Shore Data Station 2015 Data')
plt.xlabel('PC1 loading')
plt.ylabel('PC2 loading')

variables = ['temp', 'sal', 'fluor', 'pH', 'do2']
for i, txt in enumerate (variables):
    plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
    plt.text(A[i,0], A[i,1], txt)
# Out:
# PC1 loading
# [ 0.89812298 -0.70129656  0.16392789  0.85733613  0.92062405]
# temp sal fluor pH do2

# %%
tau = np.dot(PCA_df15, vec)
tau

np.shape(tau)
# Out:
# (82921, 5)

# %%
plt.plot(tau[:,1]) #PC1
plt.plot(tau[:,2]) #PC2
plt.plot(tau[:,3]) #PC3
plt.plot(tau[:,4]) #PC4
#plt.plot(tau[:,5]) #PC5

# %%
from scipy.signal import periodogram
from scipy.signal import welch

f,S = periodogram(PCA_df15['temp'],fs=288)
plt.figure()
plt.loglog(f,S,'k-')
plt.xlabel('frequency [int_ctd_pressure]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
plt.title('[periodogram, temp for 2015]')
# Out:
# Text(0.5, 1.0, '[periodogram, temp for 2015]')

# %%
N = len(PCA_df15['temp'])
fs = 288 
fN = 0.5* fs

# %%
PCA_df15['temp']
# Out:
# 0        13.706210
# 1        13.711299
# 2        13.731653
# 3        13.718933
# 4        13.755392
#            ...
# 82916    14.457828
# 82917    14.445045
# 82918    14.406686
# 82919    14.082456
# 82920    14.148172
# Name: temp, Length: 82921, dtype: float64

# %%
plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df15['temp'], fs=288., nperseg=winlen, window='hanning') 
plt.ylim(.0000000001) #use these to look at specific parts of the periodogram
plt.xlim(.01) #use these to look at specific parts of the periodogram
# Out:
# (0.01, 245.04097933053583)

# %%
#raw periodogram (noisy, biased)
f, S = welch(PCA_df15['temp'], fs=288, nperseg=N) #window='boxcar'

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('($^\circ$C)2')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (PCA_df15['temp'], fs=288., nperseg=winlen, window='hanning') 
#weighs middle more than edges like boxcar

plt.loglog(f2,S2)

# confidence intervals 

from scipy.stats import chi2

dof = N/winlen/2 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning) :)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
dof = N/winlen/8 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
#Wind data
