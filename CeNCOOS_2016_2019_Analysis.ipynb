# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from matplotlib import mlab
import scipy.signal as signal
from scipy import stats
import pandas as pd
from scipy import linalg
import os

# %% [markdown]
# *MLML Shore Station Data>Moss_Landing>netcdf*
# https://drive.google.com/drive/u/3/folders/1kHGUe0LtATtH5veMkt-f35pgTuz2AGWZ

# %%
local_dataset_2016='Data/moss_landing_2016.nc'
local_dataset_2017 = 'Data/moss_landing_2017.nc'
local_dataset_2018='Data/moss_landing_2018.nc'
local_dataset_2019='Data/moss_landing_2019.nc'

# %%
ds2016= xr.open_dataset(local_dataset_2016)
ds2017=xr.open_dataset(local_dataset_2017)
ds2018=xr.open_dataset(local_dataset_2018)
ds2019=xr.open_dataset(local_dataset_2019)

# %%
df=ds2016.to_dataframe()
df2=ds2017.to_dataframe()
df3=ds2018.to_dataframe()
df4=ds2019.to_dataframe()

# %%
#Temp 2016
plt.figure()
plt.plot(df.index,df['temp'])
plt.title('Temp of 2016')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')

#Temp 2017
plt.figure()
plt.plot(df2.index,df2['temp'])
plt.title('Temp of 2017')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')


#Temp 2018
plt.figure()
plt.plot(df3.index,df3['temp'])
plt.title('Temp of 2018')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')

#Temp 2019
plt.figure()
plt.plot(df4.index,df4['temp'])
plt.title('Temp of 2019')
plt.ylabel('temp ($^\circ$C)')
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %% [markdown]
# **Note:No nitrate sensor was in the shore lab at this time, so no data available for nitrate between 2016 and 2017**

# %%
#Nitrate 2016
plt.figure()
plt.plot(df.index,df['nitrate'])
plt.title('Nitrate 2016')
plt.ylabel('Nitrate (uM)')
plt.xlabel('Year-Month')

#Nitrate 2017
plt.figure()
plt.plot(df2.index,df2['nitrate'])
plt.title('Nitrate 2017')
plt.ylabel('Nitrate (uM)')
plt.xlabel('Year-Month')


#Nitrate 2018
plt.figure()
plt.plot(df3.index,df3['nitrate'])
plt.title('Nitrate 2018')
plt.ylabel('Nitrate (uM)')
plt.xlabel('Year-Month')

#Nitrate 2019
plt.figure()
plt.plot(df4.index,df4['nitrate'])
plt.title('Nitrate 2019')
plt.ylabel('Nitrate (uM)')
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#Salinity 2016
plt.figure()
plt.plot(df.index,df['sal'])
plt.title('Salinity 2016')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')

#Salinity 2017
plt.figure()
plt.plot(df2.index,df2['sal'])
plt.title('Salinity 2017')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')


#Salinity 2018
plt.figure()
plt.plot(df3.index,df3['sal'])
plt.title('Salinity 2018')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')

#Salinity 2019
plt.figure()
plt.plot(df4.index,df4['sal'])
plt.title('Salinity 2019')
plt.ylabel('sal [ppt]')
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#DO 2016
plt.figure()
plt.plot(df.index,df['do2'])
plt.title('DO 2016')
plt.ylabel('DO (mg/L)')
plt.xlabel('Year-Month')

#DO  2017
plt.figure()
plt.plot(df2.index,df2['do2'])
plt.title('DO 2017')
plt.ylabel('DO (mg/L)')
plt.xlabel('Year-Month')


#DO  2018
plt.figure()
plt.plot(df3.index,df3['do2'])
plt.title('DO 2018')
plt.ylabel('DO (mg/L)')
plt.xlabel('Year-Month')

#DO 2019
plt.figure()
plt.plot(df4.index,df4['do2'])
plt.title('DO 2019')
plt.ylabel('DO (mg/L)')
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#pH 2016
plt.figure()
plt.plot(df.index,df['ph']) 
plt.title('Time Series of pH 2016')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')

#pH 2017
plt.figure()
plt.plot(df2.index,df2['ph']) 
plt.title('Time Series of pH 2017')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')

#pH 2018
plt.figure()
plt.plot(df3.index,df3['ph']) 
plt.title('Time Series of pH 2018')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')

#pH 2019
plt.figure()
plt.plot(df4.index,df4['ph']) 
plt.title('Time Series of pH 2019')
plt.ylabel('pH (-log[H +] and [H+]) ') 
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#Fluorescence
plt.figure()
plt.plot(df.index,df['fluor']) 
plt.title('Time Series of Fluor 2016')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df2.index,df2['fluor']) 
plt.title('Time Series of Fluor 2017')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df3.index,df3['fluor']) 
plt.title('Time Series of Fluor 2018')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')

#Fluorescence
plt.figure()
plt.plot(df4.index,df4['fluor']) 
plt.title('Time Series of Fluor 2019')
plt.ylabel('Fluor (RFU)') 
plt.xlabel('Year-Month')
# Out:
# Text(0.5, 0, 'Year-Month')

# %%
#Raw Data

# %%
local_dataset_2016='Data/moss_landing_2016.nc'
local_dataset_2017 = 'Data/moss_landing_2017.nc'
local_dataset_2018='Data/moss_landing_2018.nc'
local_dataset_2019='Data/moss_landing_2019.nc'

# %%
ds2016= xr.open_dataset(local_dataset_2016)
ds2017=xr.open_dataset(local_dataset_2017)
ds2018=xr.open_dataset(local_dataset_2018)
ds2019=xr.open_dataset(local_dataset_2019)

# %%
#Raw Data
df=ds2016.to_dataframe()
df2=ds2017.to_dataframe()
df3=ds2018.to_dataframe()
df4=ds2019.to_dataframe()

# %% [markdown]
# *Creating a data frame for data sets without Nan's*

# %%
#Note: 0 rows × 28 columns when code applied to df and df2. 
#Code run for df and df2 are w/o .dropna

#df=ds2016.to_dataframe().reset_index().dropna() Can't drop NA ? #2016
#df2=ds2017.to_dataframe().reset_index().dropna() Can't drop NA ? #2017


################################################################################
#Even without .dropna(), array all false and no data
#df3=ds2018.to_dataframe().reset_index().dropna() #2018
################################################################################

#Run Successful with .dropna()
df4=ds2019.to_dataframe().reset_index().dropna() #2019

# %% [markdown]
# *Creating a good set of data for the whole 2016 year with flags=1 (1 being represenative of a quality flag indicating data that has no problems based on processed quality contol data for the Shore House*

# %%
#Without .dropna () and took out (df['nitrate_flg'] == 1) & because of no nitrate sensor in 2016

# %%
ii_df=np.array((df['temp_flg'] == 1) & (df['sal_flg'] == 1) & (df['fluor_flg'] == 1) & (df['ph_flg'] == 1) & (df['do2_flg'] == 1))

# %%
temp_df= np.array(df['temp'][ii_df])
# nitrate_df = np.array(df['nitrate'][ii_df])
sal_df= np.array(df['sal'][ii_df])
fluor_df= np.array(df['fluor'][ii_df])
pH_df= np.array(df['ph'][ii_df])
do2_df= np.array(df['do2'][ii_df])

# %% [markdown]
# *In order for PCA to run, the shape for all variables selected for the analysis must be the same*

# %%
#Shape:(64518,)
# np.shape(temp_df)
# np.shape(sal_df)
# np.shape(fluor_df)
# np.shape(pH_df)
# np.shape(do2_df)

# %% [markdown]
# *Creating a good set of data for the whole 2017 year with flags=1 (1 being represenative of a quality flag indicating data that has no problems based on processed quality contol data for the Shore House*

# %%
#Without .dropna () and took out (df['nitrate_flg'] == 1) & because of no nitrate sensor in 2017

# %%
ii_df2=np.array((df2['temp_flg'] == 1) & (df2['sal_flg'] == 1) & (df2['fluor_flg'] == 1) & (df2['ph_flg'] == 1) & (df2['do2_flg'] == 1))

# %%
temp_df2= np.array(df2['temp'][ii_df2])
# nitrate_df2= np.array(df2['nitrate'][ii_df2])
sal_df2= np.array(df2['sal'][ii_df2])
fluor_df2= np.array(df2['fluor'][ii_df2])
pH_df2= np.array(df2['ph'][ii_df2])
do2_df2= np.array(df2['do2'][ii_df2])

# %% [markdown]
# *In order for PCA to run, the shape for all variables selected for the analysis must be the same*

# %%
#Shape:(21424,)
#np.shape(temp_df2)
#np.shape(sal_df2)
#np.shape(fluor_df2)
#np.shape(pH_df2)
#np.shape(do2_df2)

# %% [markdown]
# *Creating a good set of data for the whole 2018 year with flags=1 (1 being represenative of a quality flag indicating data that has no problems based on processed quality contol data for the Shore House*

# %%
#Array is all False

# %%
#df3

# %%
ii_df3=np.array((df3['temp_flg'] == 1) & (df3['sal_flg'] == 1) & (df3['fluor_flg'] == 1) & (df3['ph_flg'] == 1) & (df3['nitrate_flg'] == 1) & (df3['do2_flg'] == 1))

# %%
temp_df3= np.array(df3['temp'][ii_df3])
nitrate_df3= np.array(df3['nitrate'][ii_df3])
sal_df3= np.array(df3['sal'][ii_df3])
fluor_df3= np.array(df3['fluor'][ii_df3])
pH_df3= np.array(df3['ph'][ii_df3])
do2_df3= np.array(df3['do2'][ii_df3])

# %%
#(0,)
# np.shape(temp_df3)
#np.shape(sal_df3)
# np.shape(fluor_df3)
# np.shape(pH_df3)
# np.shape(do2_df3)

# %% [markdown]
# *Creating a good set of data for the whole 2019 year with flags=1 (1 being represenative of a quality flag indicating data that has no problems based on processed quality contol data for the Shore House*

# %%
ii_df4=np.array((df4['temp_flg'] == 1) & (df4['sal_flg'] == 1) & (df4['fluor_flg'] == 1) & (df4['ph_flg'] == 1) & (df4['nitrate_flg'] == 1) & (df4['do2_flg'] == 1))

# %%
temp_df4= np.array(df4['temp'][ii_df4])
nitrate_df4= np.array(df4['nitrate'][ii_df4])
sal_df4= np.array(df4['sal'][ii_df4])
fluor_df4= np.array(df4['fluor'][ii_df4])
pH_df4= np.array(df4['ph'][ii_df4])
do2_df4= np.array(df4['do2'][ii_df4])

# %% [markdown]
# *In order for PCA to run, the shape for all variables selected for the analysis must be the same*

# %%
#Shape:(30220,)
#np.shape(temp_df4)
#np.shape(sal_df4)
#np.shape(fluor_df4)
#np.shape(pH_df4)
#np.shape(do2_df4)

# %% [markdown]
# ### PCA Step 1: data matrix

# %% [markdown]
# *Creating a new data frame with good flag data, and creating a data matrix that standardizes the data*

# %% [markdown]
# *Note:Results of PCA depend on the scales at which the variables are measured. Variables with the highest sampling variance will tend to be emphasized in the first few principal component's. PCA using the covaiance function

# %%
PCA_df = pd.DataFrame(temp_df, columns=['temp'])
#PCA_df['nitrate'] = nitrate_df.tolist()
PCA_df['sal'] = sal_df.tolist()
PCA_df['fluor'] = fluor_df.tolist()
PCA_df['pH'] = pH_df.tolist()
PCA_df['do2'] = do2_df.tolist()

# %%
PCA_df
# Out:
#             temp        sal     fluor        pH     do2
# 0      14.352496  32.948777  0.268737  8.000960  302.52
# 1      14.357766  32.944286  0.275086  8.000960  293.98
# 2      14.355508  32.944285  0.275086  8.000960  305.25
# 3      14.354002  32.940718  0.268737  8.005254  301.00
# 4      14.362283  32.932735  0.268737  8.005254  299.99
# ...          ...        ...       ...       ...     ...
# 64513  12.119312  33.103501  1.417943  7.728100  222.70
# 64514  12.130182  33.105019  1.392546  7.732494  213.79
# 64515  12.141050  33.102481  1.392546  7.732494  212.89
# 64516  12.163556  33.095713  1.411594  7.688557  215.24
# 64517  12.522712  33.035979  1.525879  7.337061  249.97
#
# [64518 rows x 5 columns]

# %% [markdown]
# Length of values does not match length of index for everything

# %%
PCA_df2 = pd.DataFrame(temp_df, columns=['temp'])
#PCA_df2['nitrate'] = nitrate_df2.tolist()
# PCA_df2['sal'] = sal_df2.tolist()
# PCA_df2['fluor'] = fluor_df2.tolist()
# PCA_df2['pH'] = pH_df2.tolist()
# PCA_df2['do2'] = do2_df2.tolist()

# %%
#Successful, but no data in data frame

# %%
PCA_df3 = pd.DataFrame(temp_df3, columns=['temp'])
#PCA_df3['nitrate'] = nitrate_df3.tolist()
PCA_df3['sal'] = sal_df3.tolist()
PCA_df3['fluor'] = fluor_df3.tolist()
PCA_df3['pH'] = pH_df3.tolist()
PCA_df3['do2'] = do2_df3.tolist()

# %%
PCA_df3
# Out:
# Empty DataFrame
# Columns: [temp, sal, fluor, pH, do2]
# Index: []

# %%
#Successful

# %%
PCA_df4 = pd.DataFrame(temp_df4, columns=['temp'])
#PCA_df4['nitrate'] = nitrate_df4.tolist()
PCA_df4['sal'] = sal_df4.tolist()
PCA_df4['fluor'] = fluor_df4.tolist()
PCA_df4['pH'] = pH_df4.tolist()
PCA_df4['do2'] = do2_df4.tolist()

# %%
PCA_df4
# Out:
#             temp        sal     fluor        pH     do2
# 0      12.506247  33.233143  2.087664  7.820086  188.51
# 1      12.707787  33.230927  2.203415  7.640237  187.98
# 2      12.434932  33.234306  2.319166  7.679579  188.36
# 3      12.415158  33.231456  2.386687  7.831327  185.56
# 4      12.409139  33.231902  2.396333  7.820086  186.36
# ...          ...        ...       ...       ...     ...
# 30215  13.675158  32.854697  0.843342  7.996500  298.18
# 30216  13.620196  32.863286  0.872280  7.987500  299.19
# 30217  13.706426  32.862614  0.833696  7.987500  268.10
# 30218  13.604969  32.882943  0.852988  7.978500  260.44
# 30219  13.708115  32.851762  0.862634  7.992000  265.23
#
# [30220 rows x 5 columns]

# %%
# standardizing data. 
# For each column, subtract the mean and divide by the standard deviation. 
# This should transform each column into a standardized variable with a mean of 0 and a standard deviation of 1.

# %%
# env_data_norm= (env_data - np.mean(env_data, axis=0))/np.std(env_data, axis=0, ddof=1)


# col_mean = np.mean(env_data, axis=0) #axis=0, rows is axis 0 and column is axis=1. 
# col_mean #mean of each column 
# env_data-col_mean

# %% [markdown]
# ## PCA Step 2: correlation (or covariance) matrix
# Creating the correlation matrix with the standardized data.
#
# *Note:Results of PCA depend on the scales at which the variables are measured. Variables with the highest sampling variance will tend to be emphasized in the first few principal component's. PCA using the covariance function should only be considered if all variables have the same units of measurement. So therefore, below we standardize our data to make sure each variable in the PCA has equal weight to avoid this issue.

# %%
R_16 = np.corrcoef(PCA_df, rowvar=False)

# %%
R_17 = np.corrcoef(PCA_df2, rowvar=False)

# %%
R_18 = np.corrcoef(PCA_df3, rowvar=False)
# Out:
# /Users/marisolfigueroa/opt/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /Users/marisolfigueroa/opt/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:154: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /Users/marisolfigueroa/opt/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Users/marisolfigueroa/opt/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /Users/marisolfigueroa/opt/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2455: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
R_19 = np.corrcoef(PCA_df4, rowvar=False)

# %% [markdown]
# ## PCA Step 3: covariance (or correlation) matrix
#
# $ RV = V\Lambda $
#
# The eigenvalues are in the matrix $\Lambda$
#
# The eigenvectors are in the matrix $V$

# %%
val, vec = linalg.eig(R_16)

# %%
 #val, vec = linalg.eig(R_17) #expected square matrix

# %%
#val, vec = linalg.eig(R_18) #expected square matrix

# %%
val, vec = linalg.eig(R_19)

# %%
######################################################################################

# %%
#R_16=2016

# %%
PCA_df
# Out:
#             temp        sal     fluor        pH     do2
# 0      14.352496  32.948777  0.268737  8.000960  302.52
# 1      14.357766  32.944286  0.275086  8.000960  293.98
# 2      14.355508  32.944285  0.275086  8.000960  305.25
# 3      14.354002  32.940718  0.268737  8.005254  301.00
# 4      14.362283  32.932735  0.268737  8.005254  299.99
# ...          ...        ...       ...       ...     ...
# 64513  12.119312  33.103501  1.417943  7.728100  222.70
# 64514  12.130182  33.105019  1.392546  7.732494  213.79
# 64515  12.141050  33.102481  1.392546  7.732494  212.89
# 64516  12.163556  33.095713  1.411594  7.688557  215.24
# 64517  12.522712  33.035979  1.525879  7.337061  249.97
#
# [64518 rows x 5 columns]

# %%
vec
# Out:
# array([[ 0.52456847, -0.06213983, -0.79480223,  0.29854443, -0.01127858],
#        [-0.45090043,  0.09383893, -0.20474996,  0.2973403 ,  0.81089411],
#        [ 0.16187424, -0.93731522,  0.20045513,  0.06268296,  0.22610946],
#        [ 0.49184291,  0.17410052,  0.04876117, -0.67871991,  0.51453007],
#        [ 0.5033925 ,  0.28011083,  0.53273536,  0.59822245,  0.16265563]])

# %%
val = np.real(val)

# %%
np.real(val)
np.sum(val)
# Out:
# 5.0

# %%
pctvar = val/np.sum(val)*100

# %%
pctvar
# Out:
# array([64.74104807, 20.12787647,  2.9721999 ,  2.5643737 ,  9.59450185])

# %%
A = np.dot(vec, np.diag(val**.5))

# %%
A
# Out:
# array([[ 0.94379365, -0.06233816, -0.306396  ,  0.1069017 , -0.00781179],
#        [-0.8112515 ,  0.09413845, -0.07893104,  0.10647053,  0.56164302],
#        [ 0.29124106, -0.94030696,  0.07727539,  0.02244529,  0.15660836],
#        [ 0.88491444,  0.17465622,  0.01879742, -0.24303356,  0.35637479],
#        [ 0.90569424,  0.28100489,  0.20536931,  0.21420932,  0.11265885]])

# %%
print('PC1 loading')
print(A[:,0])
print('temp', 'nitrate', 'sal', 'fluor', 'pH', 'do2')
# Out:
# PC1 loading
# [ 0.94379365 -0.8112515   0.29124106  0.88491444  0.90569424]
# temp nitrate sal fluor pH do2

# %%
plt.figure
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.title('MLML Shore Data Station 2016 Data')
plt.xlabel('PC1 loading')
plt.ylabel('PC2 loading')

variables = ['temp', 'nitrate', 'sal', 'fluor', 'pH', 'do2']
for i, txt in enumerate (variables):
    plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
    plt.text(A[i,0], A[i,1], txt)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-e0f033549108> in <module>
#       8 variables = ['temp', 'nitrate', 'sal', 'fluor', 'pH', 'do2']
#       9 for i, txt in enumerate (variables):
# ---> 10     plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
#      11     plt.text(A[i,0], A[i,1], txt)
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
tau = np.dot(PCA_df, vec)
tau
# Out:
# array([[148.93726437,  88.08022484, 143.45345024, 189.64254654,
#          79.9401742 ],
#        [144.64410985,  85.68137822, 138.9018938 , 184.5343628 ,
#          78.54882941],
#        [150.31615907,  88.8383675 , 144.90761671, 191.27565512,
#          80.38198287],
#        ...,
#        [102.63870732,  62.02562979,  97.64275417, 135.66201261,
#          65.62690005],
#        [103.8180112 ,  62.65635345,  98.87985539, 137.103557  ,
#          65.98509838],
#        [121.36178746,  72.18836196, 117.11429693, 158.21501643,
#          71.42662592]])

# %%
np.shape(tau)
# Out:
# (64518, 5)

# %%
plt.figure()
plt.plot(tau[:,1]) #PC1

# %%
plt.plot(tau[:,2]) #PC2

# %%
from scipy.signal import periodogram
from scipy.signal import welch

f,S = periodogram(df['temp'],fs=12)
plt.figure()
plt.loglog(f,S,'k-')
plt.xlabel('frequency [int_ctd_pressure]')
plt.ylabel('PSD [m$^2$ s$^{-2}$ cpd$^{-1}$]')
plt.title('[periodogram, temp for 2016]')
# Out:
# Text(0.5, 1.0, '[periodogram, temp for 2016]')

# %%
N = len(df['temp'])
fs = 12 
fN = 0.5* fs

# %%
df['temp']
# Out:
# time
# 2016-01-01 08:00:00    12.290704
# 2016-01-01 08:05:00    12.302322
# 2016-01-01 08:10:00    12.306195
# 2016-01-01 08:15:00    12.304646
# 2016-01-01 08:20:00    12.293803
#                          ...
# 2016-12-31 23:35:00    12.101451
# 2016-12-31 23:40:00    12.068825
# 2016-12-31 23:45:00    12.049397
# 2016-12-31 23:50:00    12.029964
# 2016-12-31 23:55:00    12.044734
# Name: temp, Length: 100585, dtype: float64

# %%
f, S = welch(df['temp'], fs=48, nperseg=N)

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('PSD[m$^2$ s$^{-2}$ cpd$^{-1}$]')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (df['temp'], fs=48., nperseg=winlen, window='hanning') 
#plt.ylim(.00001) #use these to look at specific parts of the periodogram
#plt.xlim(.00001) #use these to look at specific parts of the periodogram 
#subset just during summer, will help fix the gap issue and the time serie will be more sationary. 
#That graph will represent more of the true data

# %%
#raw periodogram (noisy, biased)
f, S = welch(df['temp'], fs=48, nperseg=N) #window='boxcar'

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('PSD[m$^2$ s$^{-2}$ cpd$^{-1}$]')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (df['temp'], fs=48., nperseg=winlen, window='hanning') 
#weighs middle more than edges like boxcar

plt.loglog(f2,S2)

# confidence intervals 

from scipy.stats import chi2

dof = N/winlen/2 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning) :)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
dof = N/winlen/8 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')

# %%
###########################################################################################

# %%
#R_19=2019

# %%
PCA_df4
# Out:
#             temp        sal     fluor        pH     do2
# 0      12.506247  33.233143  2.087664  7.820086  188.51
# 1      12.707787  33.230927  2.203415  7.640237  187.98
# 2      12.434932  33.234306  2.319166  7.679579  188.36
# 3      12.415158  33.231456  2.386687  7.831327  185.56
# 4      12.409139  33.231902  2.396333  7.820086  186.36
# ...          ...        ...       ...       ...     ...
# 30215  13.675158  32.854697  0.843342  7.996500  298.18
# 30216  13.620196  32.863286  0.872280  7.987500  299.19
# 30217  13.706426  32.862614  0.833696  7.987500  268.10
# 30218  13.604969  32.882943  0.852988  7.978500  260.44
# 30219  13.708115  32.851762  0.862634  7.992000  265.23
#
# [30220 rows x 5 columns]

# %%
val, vec = linalg.eig(R_19)

# %%
vec
# Out:
# array([[-0.50481454,  0.2106519 ,  0.14159959, -0.82465834, -0.02600462],
#        [ 0.48895897, -0.34913053, -0.47466814, -0.45568782, -0.45394468],
#        [-0.08554364,  0.7223021 , -0.24708183,  0.21347969, -0.60360497],
#        [-0.37888243, -0.4987911 ,  0.40193644,  0.19369287, -0.6392071 ],
#        [-0.59599648, -0.2514374 , -0.72940893,  0.17087051,  0.14259495]])

# %%
val
# Out:
# array([2.05027477+0.j, 1.2443394 +0.j, 0.29891338+0.j, 0.61136398+0.j,
#        0.79510847+0.j])

# %%
val=np.real(val)

# %%
np.real(val)
# Out:
# array([2.05027477, 1.2443394 , 0.29891338, 0.61136398, 0.79510847])

# %%
np.sum(val)
# Out:
# 4.9999999999999964

# %%
pctvar
# Out:
# array([64.74104807, 20.12787647,  2.9721999 ,  2.5643737 ,  9.59450185])

# %%
A = np.dot(vec, np.diag(val**.5))

# %%
A
# Out:
# array([[-0.72283286,  0.23498211,  0.0774167 , -0.64479844, -0.02318802],
#        [ 0.70012962, -0.38945497, -0.25951517, -0.35630125, -0.40477727],
#        [-0.12248806,  0.80572771, -0.13508698,  0.16691928, -0.53822764],
#        [-0.54251343, -0.55640129,  0.21975059,  0.151448  , -0.56997365],
#        [-0.85339428, -0.28047833, -0.39878953,  0.13360325,  0.12715029]])

# %%
print('PC1 loading')
print(A[:,0])
print('temp', 'nitrate', 'sal', 'fluor', 'pH', 'do2')
# Out:
# PC1 loading
# [-0.72283286  0.70012962 -0.12248806 -0.54251343 -0.85339428]
# temp nitrate sal fluor pH do2

# %%
plt.figure
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.title('MLML Shore Data Station 2019 Data')
plt.xlabel('PC1 loading')
plt.ylabel('PC2 loading')

variables = ['temp', 'nitrate', 'sal', 'fluor', 'pH', 'do2']
for i, txt in enumerate (variables):
    plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
    plt.text(A[i,0], A[i,1], txt)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-119-0e20984e0d7b> in <module>
#       8 variables = ['temp', 'nitrate', 'sal', 'fluor', 'pH', 'do2']
#       9 for i, txt in enumerate (variables):
# ---> 10     plt.plot ([0,A[i,0]], [0, A[i,1]], '-')
#      11     plt.text(A[i,0], A[i,1], txt)
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
tau = np.dot(PCA_df4, vec)
tau
np.shape(tau)
# Out:
# (30220, 5)

# %%
plt.figure()
plt.plot(tau[:,1]) #PC1

plt.figure()
plt.plot(tau[:,2]) #PC2

# %%
from scipy.signal import periodogram
from scipy.signal import welch

f,S = periodogram(df4['temp'],fs=12)
plt.figure()
plt.loglog(f,S,'k-')
plt.xlabel('frequency [int_ctd_pressure]')
plt.ylabel('PSD [m$^2$ s$^{-2}$ cpd$^{-1}$]')
plt.title('[periodogram, temp for 2019]')
# Out:
# Text(0.5, 1.0, '[periodogram, temp for 2019]')

# %%
N = len(df['temp'])
fs = 12 
fN = 0.5* fs

# %%
df4['temp']
# Out:
# 0        13.036344
# 1        13.013629
# 2        13.008327
# 3        13.015143
# 4        13.053754
#            ...
# 99887    13.675158
# 99888    13.620196
# 99889    13.706426
# 99890    13.604969
# 99891    13.708115
# Name: temp, Length: 78489, dtype: float64

# %%
f, S = welch(df4['temp'], fs=12, nperseg=N)

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('PSD[m$^2$ s$^{-2}$ cpd$^{-1}$]')#variance per unit frequency 
winlen = N/2
f2,S2 = welch(df4['temp'], fs=48., nperseg=winlen, window='hanning') 
#plt.ylim(.00001) #use these to look at specific parts of the periodogram
#plt.xlim(.00001) #use these to look at specific parts of the periodogram
# Out:
# /Users/marisolfigueroa/opt/miniconda3/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 100585 is greater than input length  = 78489, using nperseg = 78489
#   .format(nperseg, input_length))

# %%
#raw periodogram (noisy, biased)
f, S = welch(df4['temp'], fs=48, nperseg=N) #window='boxcar'

plt.figure()
plt.loglog(f,S)
plt.xlabel('frequency[cpd]')
plt.ylabel('PSD[m$^2$ s$^{-2}$ cpd$^{-1}$]')#variance per unit frequency 
winlen = N/2
f2,S2 = welch (df4['temp'], fs=48., nperseg=winlen, window='hanning') 
#weighs middle more than edges like boxcar

plt.loglog(f2,S2)

# confidence intervals 

from scipy.stats import chi2

dof = N/winlen/2 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning) :)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# /Users/marisolfigueroa/opt/miniconda3/lib/python3.7/site-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 100585 is greater than input length  = 78489, using nperseg = 78489
#   .format(nperseg, input_length))
# Text(5, 0.01, '95%')

# %%
dof = N/winlen/8 #dof depends on window length, relative to length of time series 
edof = (8/3)*dof #bonus points for using a sensible window (Hanning)

lower = edof/chi2.ppf(0.975,edof)
upper = edof/chi2.ppf(0.025, edof)

fplot = 5 #hoirzontal position of CI on plot

Splot = 0.01 #vertical position of CI on plot

plt.plot([fplot, fplot], Splot*np.array([lower, upper]), '-k')
plt.text(fplot, Splot, '95%')
# Out:
# Text(5, 0.01, '95%')
